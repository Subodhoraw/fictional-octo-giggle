# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.prompts import PromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import os
# ----> 2 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 from langchain_community.embeddings import HuggingFaceEmbeddings
#       4 from langchain_community.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain_google_genai'

# %%
os.environ["Gemini Api key"]-"AIzaSyCgvpEIPPNU0F1I73DMqhDke7_Y7XqSOYA"

# %%
text = """
Python Tutorial
Last Updated : 08 Dec, 2025
Version Covered : Python 3.13.1

Python is one of the most popular programming languages. It is simple to use, packed with features, and supported by a wide range of libraries and frameworks. Its clean syntax makes it beginner-friendly.

Python is a high-level, interpreted programming language used in:
- Data Science
- Artificial Intelligence & Machine Learning
- Web Development
- Automation & Scripting
- DevOps and Cybersecurity

Key Features:
- Easy-to-read and clean syntax
- Beginner-friendly and highly productive
- Large ecosystem of libraries and frameworks
- Cross-platform (Windows, macOS, Linux)

Basic Code Example:

# Python Program to Print Hello World
print("Hello World!")

Output:
Hello World!

Why Learn Python?
- Requires fewer lines of code compared to Java or C++
- Rich libraries:
  - Web: Django, Flask
  - Data Science: Pandas, NumPy
  - AI/ML: TensorFlow, Scikit-learn
- Cross-platform support
- Used by top tech companies like Google, Netflix, and NASA
- High-paying job opportunities in Software Development, Data Science, and AI/ML

Python Basics:
- Installation
- Introduction
- Applications
- Input and Output
- Variables
- Keywords
- Operators
- Quiz: Basics & I/O
- Data Types
- Quiz: Data Types, Numbers, Boolean

Control Flow:
- Conditional Statements (if, elif, else)
- Loops (for, while)
- break, continue, pass
- Quiz: Control Flow, Loops

Functions:
- Function Syntax
- Pass Statement
- Global and Local Variables
- Recursion
- *args and **kwargs
- self as Default Argument
- First-Class Functions
- Lambda Functions
- map(), filter(), reduce()
- Inner Functions
- Decorators
- Quiz: Functions

Data Structures:
- Strings
- Lists
- Tuples
- Dictionaries
- Sets
- Arrays
- List Comprehension
- Quiz: Lists, Strings
- Quiz: Tuples, Dictionary
- Quiz: Sets, Arrays, List Comprehension

Collections Module:
- Counter
- Deque
- Heapq
- OrderedDict
- Defaultdict
- Quiz: Collections

Object-Oriented Programming (OOP):
- Classes and Objects
- Encapsulation
- Inheritance
- Polymorphism
- Abstraction
- Iterators
- Quiz: OOP

Exception Handling:
- Exception Handling Basics
- Built-in Exceptions
- User-defined Exceptions
- Quiz: Exception Handling

File Handling:
- Read Files
- Write/Create Files
- OS Module
- pathlib Module
- Directory Management
- Quiz: File Handling

Database Handling:
- Python MySQL
- Python MongoDB

Packages and Libraries:
- Built-in Modules
- DSA Libraries
- GUI Libraries

Python for Data Science:
Foundational Libraries:
- NumPy
- Pandas
- Matplotlib

Visualization and Statistics:
- Seaborn
- Statsmodels

Machine Learning:
- Scikit-learn
- XGBoost / LightGBM

Deep Learning:
- TensorFlow and Keras
- PyTorch

Python for Web Development:
Backend Frameworks:
- Flask
- Django

Database Integration:
- SQLite
- SQLAlchemy
- Django ORM

Frontend Integration:
- Jinja2
- Django Templates

API Development:
- Flask-RESTful
- Django REST Framework (DRF)

Practice:
- Python Quizzes
- Python Coding Problems
- Real-world Exercises

This tutorial is beginner-friendly, industry-ready, and aligned with Python 3.13.1.
"""

# %%
splitter-RecursiveCharacterTextsplitter(chunk_size-200, chunk_overlap-50)
doc =splitter.create_documents([text])

# %%
embedding -huggingfaceEmbeddings(model_name-"Sentence-tranformers/all_minilm-l6-v6")
vectorstore =FAISS.from_documents(docs,embeddings)

# %%
retriver= vectorstore.as_retriver(search.kwargs={"k":3}) #knn

# %%
def format_docs(docs):
    return "\n\n".joined(d.page_content for d in doc)

# %%
prompt = PromptTemplete(
    input_variable =["context", "questions"]
    templete=""" USE only the content below ro answer the questions.PromptTemplete      
    context :
    {context}
    
    questions : {questions}
    Answer :
    """
)

# %%
def rag_answer(query):
    r_docs = retriver.invoke(query)
    context = format_docs(r_docs)
    full_prompt = prompt.format(context=context, question=query)
    response = llm.invoke(full_prompt)
    return response.content

# %%
query = "when was the this article last updated ? "
answer = rag_answer(query)
print("Questions : ",query)
print("\nAnswer :\n",answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 query = "when was the this article last updated ? "
# ----> 2 answer = rag_answer(query)
#       3 print("Questions : ",query)
#       4 print("\nAnswer :\n",answer)
#
# NameError: name 'rag_answer' is not defined
